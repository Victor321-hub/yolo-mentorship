# %%
# Cell 1: Install YOLO
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.9 MB/s eta 0:00:00

# %%
# Cell 2: Upload image
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-53b2198b-e727-4779-975c-fb396a2568ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53b2198b-e727-4779-975c-fb396a2568ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # You can choose a different model like yolov8s.pt, yolov8m.pt, etc.
results = model("OIP.webp")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# image 1/1 /content/OIP.webp: 480x640 12 chairs, 1 dining table, 350.7ms
# Speed: 13.5ms preprocess, 350.7ms inference, 41.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Cell 4 — Show image with boxes

from IPython.display import Image as IPImage

results[0].save(filename="output_image.jpg")

IPImage("output_image.jpg")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-27d4454c-a750-4b8f-91dd-cf52da70b1e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27d4454c-a750-4b8f-91dd-cf52da70b1e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model("IMG-20251007-WA0114.jpg")

print("\n========== SECOND IMAGE RESULTS ==========")

for result in results:

    boxes = result.boxes

    if len(boxes) == 0:
        print("No objects detected.")
    else:
        print(f"Number of objects detected: {len(boxes)}\n")

        for i, box in enumerate(boxes):

            class_id = int(box.cls)

            object_name = result.names[class_id]

            confidence = float(box.conf)

            confidence_percent = confidence * 100

            print(f"Object {i+1}: {object_name}")
            print(f"Confidence: {confidence_percent:.1f}%")
            print()
# Out:
# image 1/1 /content/IMG-20251007-WA0114.jpg: 640x544 13 chairs, 309.8ms
# Speed: 9.1ms preprocess, 309.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 544)
#
# ========== SECOND IMAGE RESULTS ==========
# Number of objects detected: 13
#
# Object 1: chair
# Confidence: 74.9%
#
# Object 2: chair
# Confidence: 67.9%
#
# Object 3: chair
# Confidence: 56.8%
#
# Object 4: chair
# Confidence: 55.6%
#
# Object 5: chair
# Confidence: 52.4%
#
# Object 6: chair
# Confidence: 47.3%
#
# Object 7: chair
# Confidence: 46.2%
#
# Object 8: chair
# Confidence: 45.1%
#
# Object 9: chair
# Confidence: 42.9%
#
# Object 10: chair
# Confidence: 40.2%
#
# Object 11: chair
# Confidence: 38.8%
#
# Object 12: chair
# Confidence: 38.2%
#
# Object 13: chair
# Confidence: 25.7%

# %%
from IPython.display import Image as IPImage

results[0].save(filename="second_output.jpg")

IPImage("second_output.jpg")
